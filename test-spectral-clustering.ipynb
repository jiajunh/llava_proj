# %%
# pytorch=2.2.1
# diffusers=0.14.0
# transformers=4.29.2
# !pip install torch==2.2.1 torchvision==0.17.1 torchaudio==2.2.1 diffusers==0.14.0 transformers==4.29.2 huggingface_hub==0.25.0 jax==0.4.23 jaxlib==0.4.23
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.3/112.3 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 737.4/737.4 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 96.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 436.4/436.4 kB 29.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 63.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.2/77.2 MB 22.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 91.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 68.2 MB/s eta 0:00:00
# ...

# %%
# !pip show torch torchvision diffusers transformers huggingface_hub jax jaxlib tokenizers numpy
# !pip show distutils

# %%
# %cd "/kaggle/working/"
# !git clone https://github.com/jiajunh/layer_distributed_spectral_clustering.git
# Out:
# /kaggle/working
# Cloning into 'layer_distributed_spectral_clustering'...
# remote: Enumerating objects: 191, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 191 (delta 30), reused 42 (delta 16), pack-reused 133 (from 1)
# Receiving objects: 100% (191/191), 50.94 MiB | 35.58 MiB/s, done.
# Resolving deltas: 100% (31/31), done.

# %%
# %cd "/kaggle/working/layer_distributed_spectral_clustering"
# !git pull
# Out:
# /kaggle/working/layer_distributed_spectral_clustering
# Already up to date.

# %%
# %cd "/kaggle/working/layer_distributed_spectral_clustering/single_img"
# Out:
# /kaggle/working/layer_distributed_spectral_clustering/single_img

# %%
# %ls
# Out:
# eval_feat.py  img.jpg  main.py  model/  srun.sh  train_utils.py

# %%
bash_file_path = "/kaggle/working/layer_distributed_spectral_clustering/single_img/srun.sh"

# %%
with open(bash_file_path, "r") as file:
    for line in file:
        print(line.strip())
# Out:
# HUGGIN_TOKEN=
# python main.py --huggingface_token $HUGGIN_TOKEN \
# --img_path img.jpg \
# --model stable_diffusion \
# --noise_schedule=random --noise_sampling --noise_min_t=0 --noise_max_t=250 \
# --learning_rate=2e-3 --train_steps=2000 \
# --use_buffer_prob=0.75 --attn_buffer_size=7 \
# --num_of_eig 20

# %%
new_file_str = '''HUGGIN_TOKEN=?
python main.py --huggingface_token $HUGGIN_TOKEN \
--img_path img.jpg \
--model dino \
--noise_schedule=random \
--noise_sampling \
--noise_min_t=0 \
--noise_max_t=250 \
--learning_rate=2e-3 \
--train_steps=2000 \
--use_buffer_prob=0.75 \
--attn_buffer_size=7 \
--num_of_eig 20'''

print(new_file_str)

with open(bash_file_path, 'w') as file:
    file.write(new_file_str)

# with open(bash_file_path, "r") as file:
#     for line in file:
#         print(line.strip())
# Out:
# HUGGIN_TOKEN=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
# python main.py --huggingface_token $HUGGIN_TOKEN --img_path img.jpg --model dino --noise_schedule=random --noise_sampling --noise_min_t=0 --noise_max_t=250 --learning_rate=2e-3 --train_steps=2000 --use_buffer_prob=0.75 --attn_buffer_size=7 --num_of_eig 20

# %%
# !bash srun.sh
# Out:
# 2025-02-26 23:40:28.165841: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-26 23:40:28.376206: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-26 23:40:28.437648: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Since no pretrained weights have been provided, we load the reference pretrained DINO weights.
# Downloading: "https://dl.fbaipublicfiles.com/dino/dino_vitbase8_pretrain/dino_vitbase8_pretrain.pth" to /root/.cache/torch/hub/checkpoints/dino_vitbase8_pretrain.pth
# 100%|█████████████████████████████████████████| 327M/327M [00:01<00:00, 250MB/s]
# ...

# %%
# !ls
# Out:
# eigevector.png	img.jpg  model	     __pycache__  train_utils.py
# eval_feat.py	main.py  output.png  srun.sh

# %%
import matplotlib.pyplot as plt

image = plt.imread("output.png")
plt.imshow(image)
